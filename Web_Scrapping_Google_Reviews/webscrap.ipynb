# %%
! pip install bs4

# %%
from bs4 import BeautifulSoup

html = '''<a href="some_url">next</a>
<span class="class"><a href="another_url">later</a></span>'''

soup = BeautifulSoup(html)

for a in soup.find_all('a', href=True):
    print("Found the URL:", a['href'])
# Out:
# Found the URL: some_url
# Found the URL: another_url

# %%
#importing libraries and setup
import urllib.request as urllib2

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

site= "https://m.mouthshut.com/product-reviews/Woodlands-Hospital-and-Medical-Research-Centre-Kolkata-reviews-925095612"
hdr = {'User-Agent': 'Mozilla/5.0'}
req = Request(site,headers=hdr)
page = urlopen(req)
soup = BeautifulSoup(page, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head id="Head1"><title>
# 	WOODLANDS HOSPITAL AND MEDICAL RESEARCH CENTRE - KOLKATA Reviews, Medical Clinic, WOODLANDS HOSPITAL AND MEDICAL RESEARCH CENTRE - KOLKATA Medical Center, Health Clinic, Equipments
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head id="Head1">
#   <title>
#    WOODLANDS HOSPITAL AND MEDICAL RESEARCH CENTRE - KOLKATA Reviews, Medical Clinic, WOODLANDS HOSPITAL AND MEDICAL RESEARCH CENTRE - KOLKATA Medical Center, Health Clinic, Equipments
#   </title>
#   <link href="https://www.mouthshut.com/product-reviews/Woodlands-Hospital-and-Medical-Research-Centre-Kolkata-reviews-925095612" rel="canonical"/>
#   <link href="https://m.mouthshut.com/product-reviews/Woodlands-Hospital-and-Medical-Research-Centre-Kolkata-reviews-925095612-page-2" rel="next"/>
#   <meta content="PdX12bcjDhrIoxVbtNQ4yBIdbPluIHXAnW6ro2U9pRY" name="google-site-verification"/>
#   <meta content="width=device-width; initial-scale=1; maximum-scale=6" name="viewport"/>
# ...

# %%
review= []
for i in soup.find_all('span', {'class':'review-holder'}):
   per_review = i.find('product-review-content')
   print(per_review) 
   review.append(per_preview)

print(review)
# Out:
# []

# %%
import pandas as pd
df = pd.DataFrame({'review':[]})

# %%
     url = (f'https://m.mouthshut.com/product-reviews/Woodlands-Hospital-and-Medical-Research-Centre-Kolkata-reviews-925095612')
     hdr = {'User-Agent':'Mozilla/5.0 Gecko/20100101 Firefox/33.0 GoogleChrome/10.0'}
     req = Request(url,headers=hdr)
     page = urlopen(req)
     #page = Requests.get(url,headers = header)
     soup = BeautifulSoup(page, 'lxml')
     results = soup.find_all("span", { "class":'review-holder'})
     #elems = results.find_all("span", { "class":'review-holder'})
     for result in results:
         review = result.find('product-review-content')
         df = df.append({
          'review': review.text,
            }, ignore_index=True)

# %%
df
# Out:
# Empty DataFrame
# Columns: [review]
# Index: []
